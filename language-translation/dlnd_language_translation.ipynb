# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
import re

def text_to_ids_single(text, vocab_to_int,is_target_text=False):
    text = re.split('\n', text)
    id_text = list()
    for line in text:
        words = re.split(' ', line)
        line_id = [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in words]
        if(is_target_text):
            line_id.append(vocab_to_int['<EOS>'])
        id_text += [line_id]
    return id_text

def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    
    # TODO: Implement Function
    source_id_text = text_to_ids_single(source_text, source_vocab_to_int,False)
    target_id_text = text_to_ids_single(target_text, target_vocab_to_int,True)
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\ipykernel\__main__.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs           = tf.placeholder(dtype=tf.int32, shape=(None, None), name="input")
    targets          = tf.placeholder(dtype=tf.int32, shape=(None, None), name="target")
    learning_rate    = tf.placeholder(dtype=tf.float32, name="learning_rate")
    keep_probability = tf.placeholder(dtype=tf.float32, name="keep_prob")
    
    return inputs, targets, learning_rate, keep_probability

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    result        = tf.concat([tf.fill([batch_size, 1],\
                               target_vocab_to_int['<GO>']),\
                               tf.strided_slice(target_data, [0, 0], \
                               [batch_size, -1], [1, 1])], 1)
    
    return result

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    cell = tf.contrib.rnn.LSTMCell(rnn_size)
    cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers)
    _, rnn_state = tf.nn.dynamic_rnn(cell = cell, inputs = rnn_inputs, dtype=tf.float32)
    
    return rnn_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    print('-----decoding_layer_train:-----')
    [print(i) for i in[encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob]]
    
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    train_pred,_,_ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    
    train_logits =  output_fn(train_pred)
    
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# -----decoding_layer_train:-----
# (LSTMStateTuple(c=<tf.Tensor 'decoding/Placeholder_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'decoding/Placeholder_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'decoding/Placeholder_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'decoding/Placeholder_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'decoding/Placeholder_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'decoding/Placeholder_3:0' shape=(?, 512) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D65C05F3C8>
# Tensor("decoding/Placeholder:0", shape=(64, 22, 200), dtype=float32)
# 22
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D65C05F550>
# <function test_decoding_layer_train.<locals>.<lambda> at 0x000001D65AE0CD90>
# Tensor("decoding/Placeholder_1:0", dtype=float32)
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    print('-----decoding_layer_infer:-----')
    [print(i) for i in[encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob]]
        
    
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, 
                                                                      encoder_state, 
                                                                      dec_embeddings, 
                                                                      start_of_sequence_id, 
                                                                      end_of_sequence_id, 
                                                                      maximum_length,
                                                                      vocab_size)
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    
    return inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# -----decoding_layer_infer:-----
# (LSTMStateTuple(c=<tf.Tensor 'decoding/Placeholder_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'decoding/Placeholder_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'decoding/Placeholder_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'decoding/Placeholder_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'decoding/Placeholder_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'decoding/Placeholder_3:0' shape=(?, 512) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D65C279BA8>
# Tensor("decoding/Placeholder:0", shape=(1000, 200), dtype=float32)
# 10
# 20
# 22
# 1000
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D65C245CC0>
# <function test_decoding_layer_infer.<locals>.<lambda> at 0x000001D65C226378>
# Tensor("decoding/Placeholder_1:0", dtype=float32)
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    print('-----decoding_layer:-----')
    [print(i) for i in[dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob]]
                       
    # TODO: Implement Function
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    
    with tf.variable_scope("decoding") as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        training_logit = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)
    
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        inference_logits = decoding_layer_infer(encoder_state, 
                                                dec_cell, 
                                                dec_embeddings, 
                                                target_vocab_to_int['<GO>'], 
                                                target_vocab_to_int['<EOS>'], 
            sequence_length, vocab_size, decoding_scope, output_fn, keep_prob)
        
    return training_logit, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# -----decoding_layer:-----
# Tensor("Placeholder:0", shape=(64, 22, 200), dtype=float32)
# Tensor("Placeholder_1:0", shape=(1000, 200), dtype=float32)
# (LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>))
# 1000
# 22
# 512
# 3
# {'<EOS>': 1, '<GO>': 3}
# Tensor("Placeholder_2:0", dtype=float32)
# -----decoding_layer_train:-----
# (LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D65C4F8C18>
# Tensor("Placeholder:0", shape=(64, 22, 200), dtype=float32)
# 22
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D65C4F8E80>
# <function decoding_layer.<locals>.<lambda> at 0x000001D65C18F950>
# Tensor("Placeholder_2:0", dtype=float32)
# -----decoding_layer_infer:-----
# (LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'Placeholder_3:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'Placeholder_4:0' shape=(?, 512) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D65C4F8C18>
# Tensor("Placeholder_1:0", shape=(1000, 200), dtype=float32)
# 3
# 1
# 22
# 1000
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D65C4F8CC0>
# <function decoding_layer.<locals>.<lambda> at 0x000001D65C18F950>
# Tensor("Placeholder_2:0", dtype=float32)
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    print('-----seq2seq_model:-----')
    [print(i) for i in[input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int]]
    
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    encoder_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    training_logit, inference_logits = decoding_layer(dec_embed_input, 
                                                      dec_embeddings, 
                                                      encoder_state, 
                                                      target_vocab_size, 
                                                      sequence_length, 
                                                      rnn_size,
                                                      num_layers, 
                                                      target_vocab_to_int, 
                                                      keep_prob)
    
    return training_logit, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# -----seq2seq_model:-----
# Tensor("Placeholder:0", shape=(64, 22), dtype=int32)
# Tensor("Placeholder_1:0", shape=(64, 22), dtype=int32)
# Tensor("Placeholder_2:0", dtype=float32)
# 64
# 22
# 200
# 300
# 64
# 80
# 512
# 3
# {'<EOS>': 1, '<GO>': 3}
# -----decoding_layer:-----
# Tensor("embedding_lookup:0", shape=(64, 22, 80), dtype=float32)
# Tensor("Variable/read:0", shape=(300, 80), dtype=float32)
# (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_5:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_6:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_7:0' shape=(?, 512) dtype=float32>))
# 300
# 22
# 512
# 3
# {'<EOS>': 1, '<GO>': 3}
# Tensor("Placeholder_2:0", dtype=float32)
# -----decoding_layer_train:-----
# (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_5:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_6:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_7:0' shape=(?, 512) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D65AE032B0>
# Tensor("embedding_lookup:0", shape=(64, 22, 80), dtype=float32)
# 22
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D65BEDA908>
# <function decoding_layer.<locals>.<lambda> at 0x000001D65C879950>
# Tensor("Placeholder_2:0", dtype=float32)
# -----decoding_layer_infer:-----
# (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_2:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_5:0' shape=(?, 512) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_6:0' shape=(?, 512) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_7:0' shape=(?, 512) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D65AE032B0>
# Tensor("Variable/read:0", shape=(300, 80), dtype=float32)
# 3
# 1
# 22
# 300
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D65AD46D30>
# <function decoding_layer.<locals>.<lambda> at 0x000001D65C879950>
# Tensor("Placeholder_2:0", dtype=float32)
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 2**8
# RNN Size
rnn_size = 32
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 32
decoding_embedding_size = 32
# Learning Rate
learning_rate = 0.002
# Dropout Keep Probability
keep_probability = .8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x000001D65C262208>>
# Traceback (most recent call last):
#   File "C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\tensorflow\python\client\session.py", line 573, in __del__
#     try:
# KeyboardInterrupt:
# -----seq2seq_model:-----
# Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# Tensor("target:0", shape=(?, ?), dtype=int32)
# Tensor("keep_prob:0", dtype=float32)
# 256
# Tensor("sequence_length:0", dtype=int32)
# 231
# 358
# 32
# 32
# 32
# 3
# {'pamplemousses': 186, 'banane': 187, 'êtes-vous': 4, 'frais': 188, 'où': 5, 'envisage': 8, 'bien': 9, 'traduis': 10, 'au': 11, 'trouvé': 12, 'avril': 189, 'blanc': 190, 'blanche': 191, '-': 192, 'petite': 194, 'français': 13, 'aimé': 14, 'mangue': 195, 'gèle': 15, 'trop': 69, 'sont': 16, 'comment': 17, 'grande': 196, 'mangues': 19, 'aimons': 20, 'aimée': 21, 'pourquoi': 22, 'notre': 197, 'pluie': 198, 'nouveau': 23, 'détestez': 199, 'conduit': 245, 'leurs': 90, "l'automne": 24, 'vit': 215, 'détestons': 330, 'bénigne': 200, 'votre': 25, 'brillante': 6, 'chaude': 26, "l'ours": 201, 'les': 202, 'jersey': 203, 'sur': 27, 'volant': 206, '<GO>': 3, "l'": 207, 'voulait': 208, 'leur': 29, 'février': 7, 'mon': 209, 'juin': 30, 'enneigé': 31, 'mouillée': 211, 'brillant': 212, 'été': 342, 'pleut': 213, 'doux': 214, 'tour': 33, 'prévoit': 34, "l'éléphant": 61, 'qui': 35, 'fraises': 37, 'un': 217, 'douce': 128, 'inde': 219, 'occupé': 220, 'aimé.': 36, 'magnifique': 119, 'souris': 38, 'détendre': 221, 'vos': 222, 'ressort': 223, 'mai': 62, 'cet': 40, 'mais': 224, 'je': 41, 'allés': 225, 'jaune': 42, 'lapin': 43, 'california': 44, "n'est": 227, 'rendre': 228, 'visite': 45, 'peu': 229, 'clémentes': 46, 'neige': 230, 'et': 47, 'comme': 233, 'requin': 48, 'frisquet': 235, 'aimeraient': 49, 'bleu': 50, 'faire': 306, '<EOS>': 1, 'que': 236, 'cette': 32, 'congélation': 52, 'ses': 237, 'printemps': 238, 'redoutée': 193, 'chiens': 129, 'il': 183, 'chats': 239, 'vieux': 54, 'facile': 55, 'nouvelle': 240, "l'orange": 241, 'redouté': 242, 'préférée': 57, 'citron': 58, 'cheval': 243, 'pense': 97, 'aimez': 131, 'voulaient': 244, 'chine': 339, 'entre': 59, 'froid': 246, 'dans': 247, 'vers': 39, 'tranquille': 60, 'décembre': 249, 'aimés': 250, 'grosses': 65, 'habituellement': 64, 'détestait': 251, 'pourrait': 252, "n'aime": 253, 'bleue': 254, 'rouillée': 66, '?': 256, 'pourraient': 67, 'dernier': 68, 'parfois': 134, 'pêche': 70, 'enneigée': 281, 'aiment': 71, "qu'elle": 257, 'maillot': 258, 'porcelaine': 72, 'neigeux': 259, 'noire': 260, 'sèche': 135, 'pousse': 73, 'ils': 261, 'chat': 74, 'veut': 263, 'automobile': 75, 'elle': 264, 'pluvieux': 76, 'aux': 265, 'en': 266, 'son': 267, 'moindres': 77, 'raisins': 78, 'vieille': 79, 'lac': 268, 'californie': 80, 'veulent': 81, 'novembre': 82, "n'a": 284, 'occupée': 83, 'préféré.': 84, "l'épicerie": 255, 'pêches': 139, 'étaient': 85, '.': 18, 'tout': 86, 'lion': 270, 'durant': 271, 'grosse': 87, 'noir': 88, 'beau': 89, 'préféré': 226, 'petites': 262, 'grand': 91, 'pluies': 108, 'mars': 273, 'fruit': 184, 'favori': 274, 'préférés': 92, 'déteste': 93, 'une': 275, 'hiver': 94, 'fait': 140, 'août': 95, 'traduire': 276, "n'aiment": 96, 'vont': 277, 'chaux': 278, "l'oiseau": 279, 'dernière': 280, 'allions': 282, "j'aime": 99, 'requins': 283, 't': 100, 'gros': 285, 'intention': 63, 'espagnol': 286, 'es-tu': 287, 'vert': 288, 'eiffel': 101, 'avez': 289, 'janvier': 102, 'calme': 103, 'grandes': 105, 'allez': 106, 'poire': 290, 'aiment-ils': 107, 'nous': 104, 'vous': 291, 'difficile': 293, 'new': 294, 'à': 109, 'chinois': 346, 'prévois': 295, 'oiseaux': 110, 'moteur': 111, 'pensez': 112, 'le': 296, 'pendant': 113, 'i': 114, '<PAD>': 0, 'voudrait': 115, 'rouge': 116, 'conduite': 231, 'états-unis': 117, 'souvent': 298, 'etats-unis': 118, 'cépage': 299, 'as-tu': 300, 'généralement': 120, 'sec': 121, 'détend': 122, 'allons': 123, 'humide': 124, 'football': 301, 'fraise': 125, 'monde': 232, '<UNK>': 2, "n'aimons": 302, 'amusant': 303, 'traduction': 304, 'mouillé': 305, 'apprécié': 234, 'merveilleux': 130, "l'animal": 307, 'voulez': 308, 'aime': 309, 'belle': 132, 'des': 133, 'était': 218, 'ours': 292, 'juillet': 311, 'a': 312, 'petits': 313, 'verte': 136, 'jamais': 137, '-ils': 269, 'lions': 138, 'oiseau': 314, 'éléphants': 315, 'paris': 141, 'serpent': 142, 'allé': 143, 'pommes': 144, 'chien': 146, 'la': 147, 'petit': 316, "n'aimait": 149, 'plaît': 154, "n'aimez": 150, 'chaud': 317, 'conduisait': 151, '-elle': 318, 'cher': 31 ...
# -----decoding_layer:-----
# Tensor("embedding_lookup:0", shape=(256, ?, 32), dtype=float32)
# Tensor("Variable/read:0", shape=(358, 32), dtype=float32)
# (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_2:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 32) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_5:0' shape=(?, 32) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_6:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_7:0' shape=(?, 32) dtype=float32>))
# 358
# Tensor("sequence_length:0", dtype=int32)
# 32
# 3
# {'pamplemousses': 186, 'banane': 187, 'êtes-vous': 4, 'frais': 188, 'où': 5, 'envisage': 8, 'bien': 9, 'traduis': 10, 'au': 11, 'trouvé': 12, 'avril': 189, 'blanc': 190, 'blanche': 191, '-': 192, 'petite': 194, 'français': 13, 'aimé': 14, 'mangue': 195, 'gèle': 15, 'trop': 69, 'sont': 16, 'comment': 17, 'grande': 196, 'mangues': 19, 'aimons': 20, 'aimée': 21, 'pourquoi': 22, 'notre': 197, 'pluie': 198, 'nouveau': 23, 'détestez': 199, 'conduit': 245, 'leurs': 90, "l'automne": 24, 'vit': 215, 'détestons': 330, 'bénigne': 200, 'votre': 25, 'brillante': 6, 'chaude': 26, "l'ours": 201, 'les': 202, 'jersey': 203, 'sur': 27, 'volant': 206, '<GO>': 3, "l'": 207, 'voulait': 208, 'leur': 29, 'février': 7, 'mon': 209, 'juin': 30, 'enneigé': 31, 'mouillée': 211, 'brillant': 212, 'été': 342, 'pleut': 213, 'doux': 214, 'tour': 33, 'prévoit': 34, "l'éléphant": 61, 'qui': 35, 'fraises': 37, 'un': 217, 'douce': 128, 'inde': 219, 'occupé': 220, 'aimé.': 36, 'magnifique': 119, 'souris': 38, 'détendre': 221, 'vos': 222, 'ressort': 223, 'mai': 62, 'cet': 40, 'mais': 224, 'je': 41, 'allés': 225, 'jaune': 42, 'lapin': 43, 'california': 44, "n'est": 227, 'rendre': 228, 'visite': 45, 'peu': 229, 'clémentes': 46, 'neige': 230, 'et': 47, 'comme': 233, 'requin': 48, 'frisquet': 235, 'aimeraient': 49, 'bleu': 50, 'faire': 306, '<EOS>': 1, 'que': 236, 'cette': 32, 'congélation': 52, 'ses': 237, 'printemps': 238, 'redoutée': 193, 'chiens': 129, 'il': 183, 'chats': 239, 'vieux': 54, 'facile': 55, 'nouvelle': 240, "l'orange": 241, 'redouté': 242, 'préférée': 57, 'citron': 58, 'cheval': 243, 'pense': 97, 'aimez': 131, 'voulaient': 244, 'chine': 339, 'entre': 59, 'froid': 246, 'dans': 247, 'vers': 39, 'tranquille': 60, 'décembre': 249, 'aimés': 250, 'grosses': 65, 'habituellement': 64, 'détestait': 251, 'pourrait': 252, "n'aime": 253, 'bleue': 254, 'rouillée': 66, '?': 256, 'pourraient': 67, 'dernier': 68, 'parfois': 134, 'pêche': 70, 'enneigée': 281, 'aiment': 71, "qu'elle": 257, 'maillot': 258, 'porcelaine': 72, 'neigeux': 259, 'noire': 260, 'sèche': 135, 'pousse': 73, 'ils': 261, 'chat': 74, 'veut': 263, 'automobile': 75, 'elle': 264, 'pluvieux': 76, 'aux': 265, 'en': 266, 'son': 267, 'moindres': 77, 'raisins': 78, 'vieille': 79, 'lac': 268, 'californie': 80, 'veulent': 81, 'novembre': 82, "n'a": 284, 'occupée': 83, 'préféré.': 84, "l'épicerie": 255, 'pêches': 139, 'étaient': 85, '.': 18, 'tout': 86, 'lion': 270, 'durant': 271, 'grosse': 87, 'noir': 88, 'beau': 89, 'préféré': 226, 'petites': 262, 'grand': 91, 'pluies': 108, 'mars': 273, 'fruit': 184, 'favori': 274, 'préférés': 92, 'déteste': 93, 'une': 275, 'hiver': 94, 'fait': 140, 'août': 95, 'traduire': 276, "n'aiment": 96, 'vont': 277, 'chaux': 278, "l'oiseau": 279, 'dernière': 280, 'allions': 282, "j'aime": 99, 'requins': 283, 't': 100, 'gros': 285, 'intention': 63, 'espagnol': 286, 'es-tu': 287, 'vert': 288, 'eiffel': 101, 'avez': 289, 'janvier': 102, 'calme': 103, 'grandes': 105, 'allez': 106, 'poire': 290, 'aiment-ils': 107, 'nous': 104, 'vous': 291, 'difficile': 293, 'new': 294, 'à': 109, 'chinois': 346, 'prévois': 295, 'oiseaux': 110, 'moteur': 111, 'pensez': 112, 'le': 296, 'pendant': 113, 'i': 114, '<PAD>': 0, 'voudrait': 115, 'rouge': 116, 'conduite': 231, 'états-unis': 117, 'souvent': 298, 'etats-unis': 118, 'cépage': 299, 'as-tu': 300, 'généralement': 120, 'sec': 121, 'détend': 122, 'allons': 123, 'humide': 124, 'football': 301, 'fraise': 125, 'monde': 232, '<UNK>': 2, "n'aimons": 302, 'amusant': 303, 'traduction': 304, 'mouillé': 305, 'apprécié': 234, 'merveilleux': 130, "l'animal": 307, 'voulez': 308, 'aime': 309, 'belle': 132, 'des': 133, 'était': 218, 'ours': 292, 'juillet': 311, 'a': 312, 'petits': 313, 'verte': 136, 'jamais': 137, '-ils': 269, 'lions': 138, 'oiseau': 314, 'éléphants': 315, 'paris': 141, 'serpent': 142, 'allé': 143, 'pommes': 144, 'chien': 146, 'la': 147, 'petit': 316, "n'aimait": 149, 'plaît': 154, "n'aimez": 150, 'chaud': 317, 'conduisait': 151, '-elle': 318, 'cher': 31 ...
# Tensor("keep_prob:0", dtype=float32)
# -----decoding_layer_train:-----
# (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_2:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 32) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_5:0' shape=(?, 32) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_6:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_7:0' shape=(?, 32) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D657F1A908>
# Tensor("embedding_lookup:0", shape=(256, ?, 32), dtype=float32)
# Tensor("sequence_length:0", dtype=int32)
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D657F1AB38>
# <function decoding_layer.<locals>.<lambda> at 0x000001D65AE0C950>
# Tensor("keep_prob:0", dtype=float32)
# -----decoding_layer_infer:-----
# (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_2:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 32) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_5:0' shape=(?, 32) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_6:0' shape=(?, 32) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_7:0' shape=(?, 32) dtype=float32>))
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x000001D657F1A908>
# Tensor("Variable/read:0", shape=(358, 32), dtype=float32)
# 3
# 1
# Tensor("sequence_length:0", dtype=int32)
# 358
# <tensorflow.python.ops.variable_scope.VariableScope object at 0x000001D657F2ACF8>
# <function decoding_layer.<locals>.<lambda> at 0x000001D65AE0C950>
# Tensor("keep_prob:0", dtype=float32)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.876
# Epoch   0 Batch    1/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.874
# Epoch   0 Batch    2/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.868
# Epoch   0 Batch    3/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.889
# Epoch   0 Batch    4/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.876
# Epoch   0 Batch    5/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.863
# Epoch   0 Batch    6/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.871
# Epoch   0 Batch    7/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.866
# Epoch   0 Batch    8/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.863
# Epoch   0 Batch    9/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.874
# Epoch   0 Batch   10/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.867
# Epoch   0 Batch   11/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.850
# Epoch   0 Batch   12/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.855
# Epoch   0 Batch   13/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.864
# Epoch   0 Batch   14/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.850
# Epoch   0 Batch   15/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.843
# Epoch   0 Batch   16/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.819
# Epoch   0 Batch   17/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.832
# Epoch   0 Batch   18/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.822
# Epoch   0 Batch   19/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.811
# Epoch   0 Batch   20/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.836
# Epoch   0 Batch   21/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.831
# Epoch   0 Batch   22/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.811
# Epoch   0 Batch   23/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.795
# Epoch   0 Batch   24/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.809
# Epoch   0 Batch   25/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.829
# Epoch   0 Batch   26/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.795
# Epoch   0 Batch   27/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.772
# Epoch   0 Batch   28/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.783
# Epoch   0 Batch   29/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.808
# Epoch   0 Batch   30/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.735
# Epoch   0 Batch   31/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.777
# Epoch   0 Batch   32/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.753
# Epoch   0 Batch   33/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.706
# Epoch   0 Batch   34/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.694
# Epoch   0 Batch   35/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.767
# Epoch   0 Batch   36/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.772
# Epoch   0 Batch   37/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.765
# Epoch   0 Batch   38/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.714
# Epoch   0 Batch   39/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.713
# Epoch   0 Batch   40/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.648
# Epoch   0 Batch   41/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.643
# Epoch   0 Batch   42/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.678
# Epoch   0 Batch   43/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.571
# Epoch   0 Batch   44/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.593
# Epoch   0 Batch   45/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.539
# Epoch   0 Batch   46/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.549
# Epoch   0 Batch   47/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.551
# Epoch   0 Batch   48/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.437
# Epoch   0 Batch   49/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.484
# Epoch   0 Batch   50/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.727
# Epoch   0 Batch   51/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.383
# Epoch   0 Batch   52/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.479
# Epoch   0 Batch   53/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.577
# Epoch   0 Batch   54/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.511
# Epoch   0 Batch   55/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.315
# Epoch   0 Batch   56/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.375
# Epoch   0 Batch   57/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.335
# Epoch   0 Batch   58/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.426
# Epoch   0 Batch   59/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.215
# Epoch   0 Batch   60/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.306
# Epoch   0 Batch   61/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.416
# Epoch   0 Batch   62/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.338
# Epoch   0 Batch   63/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.185
# Epoch   0 Batch   64/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.104
# Epoch   0 Batch   65/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.150
# Epoch   0 Batch   66/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.266
# Epoch   0 Batch   67/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.335
# Epoch   0 Batch   68/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.357
# Epoch   0 Batch   69/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.967
# Epoch   0 Batch   70/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.105
# Epoch   0 Batch   71/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.638
# Epoch   0 Batch   72/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.955
# Epoch   0 Batch   73/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.544
# Epoch   0 Batch   74/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.878
# Epoch   0 Batch   75/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.261
# Epoch   0 Batch   76/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.012
# Epoch   0 Batch   77/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.628
# Epoch   0 Batch   78/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.096
# Epoch   0 Batch   79/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.074
# Epoch   0 Batch   80/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.207
# Epoch   0 Batch   81/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.857
# Epoch   0 Batch   82/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.092
# Epoch   0 Batch   83/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.203
# Epoch   0 Batch   84/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.713
# Epoch   0 Batch   85/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.253
# Epoch   0 Batch   86/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.044
# Epoch   0 Batch   87/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.922
# Epoch   0 Batch   88/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.790
# Epoch   0 Batch   89/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.517
# Epoch   0 Batch   90/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.778
# Epoch   0 Batch   91/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.799
# Epoch   0 Batch   92/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.835
# Epoch   0 Batch   93/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.984
# Epoch   0 Batch   94/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.956
# Epoch   0 Batch   95/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.686
# Epoch   0 Batch   96/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.935
# Epoch   0 Batch   97/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.180
# Epoch   0 Batch   98/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.921
# Epoch   0 Batch   99/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.737
# Epoch   0 Batch  100/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.616
# Epoch   0 Batch  101/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.799
# Epoch   0 Batch  102/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.802
# Epoch   0 Batch  103/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.948
# Epoch   0 Batch  104/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.824
# Epoch   0 Batch  105/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.441
# Epoch   0 Batch  106/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.824
# Epoch   0 Batch  107/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.603
# Epoch   0 Batch  108/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.825
# Epoch   0 Batch  109/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.474
# Epoch   0 Batch  110/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.707
# Epoch   0 Batch  111/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.812
# Epoch   0 Batch  112/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.571
# Epoch   0 Batch  113/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.465
# Epoch   0 Batch  114/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.606
# Epoch   0 Batch  115/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.300
# Epoch   0 Batch  116/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.757
# Epoch   0 Batch  117/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.771
# Epoch   0 Batch  118/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.529
# Epoch   0 Batch  119/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.499
# Epoch   0 Batch  120/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.460
# Epoch   0 Batch  121/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.323
# Epoch   0 Batch  122/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.913
# Epoch   0 Batch  123/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.307
# Epoch   0 Batch  124/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.323
# Epoch   0 Batch  125/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.759
# Epoch   0 Batch  126/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.462
# Epoch   0 Batch  127/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.427
# Epoch   0 Batch  128/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.541
# Epoch   0 Batch  129/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.620
# Epoch   0 Batch  130/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.643
# Epoch   0 Batch  131/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.153
# Epoch   0 Batch  132/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.698
# Epoch   0 Batch  133/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.664
# Epoch   0 Batch  134/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.642
# Epoch   0 Batch  135/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.354
# Epoch   0 Batch  136/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.334
# Epoch   0 Batch  137/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.206
# Epoch   0 Batch  138/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.700
# Epoch   0 Batch  139/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.769
# Epoch   0 Batch  140/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.406
# Epoch   0 Batch  141/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.173
# Epoch   0 Batch  142/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.208
# Epoch   0 Batch  143/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.133
# Epoch   0 Batch  144/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.510
# Epoch   0 Batch  145/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.086
# Epoch   0 Batch  146/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.768
# Epoch   0 Batch  147/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.264
# Epoch   0 Batch  148/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.183
# Epoch   0 Batch  149/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.893
# Epoch   0 Batch  150/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.183
# Epoch   0 Batch  151/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.232
# Epoch   0 Batch  152/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.300
# Epoch   0 Batch  153/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.632
# Epoch   0 Batch  154/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.915
# Epoch   0 Batch  155/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.319
# Epoch   0 Batch  156/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.108
# Epoch   0 Batch  157/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.195
# Epoch   0 Batch  158/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.278
# Epoch   0 Batch  159/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.252
# Epoch   0 Batch  160/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.289
# Epoch   0 Batch  161/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.384
# Epoch   0 Batch  162/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.450
# Epoch   0 Batch  163/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.613
# Epoch   0 Batch  164/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.254
# Epoch   0 Batch  165/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.434
# Epoch   0 Batch  166/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.202
# Epoch   0 Batch  167/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.319
# Epoch   0 Batch  168/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.416
# Epoch   0 Batch  169/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.212
# Epoch   0 Batch  170/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.541
# Epoch   0 Batch  171/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.541
# Epoch   0 Batch  172/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.117
# Epoch   0 Batch  173/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.463
# Epoch   0 Batch  174/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.498
# Epoch   0 Batch  175/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.262
# Epoch   0 Batch  176/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.404
# Epoch   0 Batch  177/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.689
# Epoch   0 Batch  178/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.660
# Epoch   0 Batch  179/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.446
# Epoch   0 Batch  180/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.292
# Epoch   0 Batch  181/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.565
# Epoch   0 Batch  182/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.666
# Epoch   0 Batch  183/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.000, Loss:  4.112
# Epoch   0 Batch  184/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.410
# Epoch   0 Batch  185/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.445
# Epoch   0 Batch  186/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.494
# Epoch   0 Batch  187/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.496
# Epoch   0 Batch  188/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.579
# Epoch   0 Batch  189/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.257
# Epoch   0 Batch  190/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.688
# Epoch   0 Batch  191/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.454
# Epoch   0 Batch  192/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.236
# Epoch   0 Batch  193/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.515
# Epoch   0 Batch  194/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.098
# Epoch   0 Batch  195/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.562
# Epoch   0 Batch  196/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.045
# Epoch   0 Batch  197/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.159
# Epoch   0 Batch  198/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.390
# Epoch   0 Batch  199/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.064
# Epoch   0 Batch  200/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.649
# Epoch   0 Batch  201/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.194
# Epoch   0 Batch  202/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.495
# Epoch   0 Batch  203/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.671
# Epoch   0 Batch  204/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.323
# Epoch   0 Batch  205/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.307
# Epoch   0 Batch  206/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.168
# Epoch   0 Batch  207/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  3.943
# Epoch   0 Batch  208/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.109
# Epoch   0 Batch  209/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.268
# Epoch   0 Batch  210/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  3.874
# Epoch   0 Batch  211/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.567
# Epoch   0 Batch  212/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.443
# Epoch   0 Batch  213/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.306
# Epoch   0 Batch  214/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.043
# Epoch   0 Batch  215/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.244
# Epoch   0 Batch  216/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.224
# Epoch   0 Batch  217/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  5.086
# Epoch   0 Batch  218/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.000, Loss:  4.613
# Epoch   0 Batch  219/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.000, Loss:  4.001
# Epoch   0 Batch  220/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.299
# Epoch   0 Batch  221/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.429
# Epoch   0 Batch  222/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.160
# Epoch   0 Batch  223/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.348
# Epoch   0 Batch  224/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.490
# Epoch   0 Batch  225/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.391
# Epoch   0 Batch  226/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.254
# Epoch   0 Batch  227/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.236
# Epoch   0 Batch  228/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.011
# Epoch   0 Batch  229/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  4.185
# Epoch   0 Batch  230/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.381
# Epoch   0 Batch  231/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.798
# Epoch   0 Batch  232/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.274
# Epoch   0 Batch  233/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.346
# Epoch   0 Batch  234/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.302
# Epoch   0 Batch  235/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.291
# Epoch   0 Batch  236/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.063
# Epoch   0 Batch  237/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.358
# Epoch   0 Batch  238/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.389
# Epoch   0 Batch  239/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.103
# Epoch   0 Batch  240/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.066
# Epoch   0 Batch  241/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.386
# Epoch   0 Batch  242/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.544
# Epoch   0 Batch  243/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.291
# Epoch   0 Batch  244/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.018
# Epoch   0 Batch  245/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.187
# Epoch   0 Batch  246/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.335
# Epoch   0 Batch  247/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.432
# Epoch   0 Batch  248/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  4.312
# Epoch   0 Batch  249/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.000
# Epoch   0 Batch  250/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.501
# Epoch   0 Batch  251/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.090
# Epoch   0 Batch  252/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.938
# Epoch   0 Batch  253/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.041
# Epoch   0 Batch  254/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.529
# Epoch   0 Batch  255/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  3.970
# Epoch   0 Batch  256/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.050
# Epoch   0 Batch  257/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.847
# Epoch   0 Batch  258/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.301
# Epoch   0 Batch  259/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.571
# Epoch   0 Batch  260/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.119
# Epoch   0 Batch  261/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.901
# Epoch   0 Batch  262/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.194
# Epoch   0 Batch  263/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.157
# Epoch   0 Batch  264/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.169
# Epoch   0 Batch  265/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.072
# Epoch   0 Batch  266/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.834
# Epoch   0 Batch  267/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.272
# Epoch   0 Batch  268/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.976
# Epoch   0 Batch  269/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  4.522
# Epoch   0 Batch  270/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.960
# Epoch   0 Batch  271/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.337
# Epoch   0 Batch  272/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.976
# Epoch   0 Batch  273/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.796
# Epoch   0 Batch  274/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.130
# Epoch   0 Batch  275/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.979
# Epoch   0 Batch  276/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.228
# Epoch   0 Batch  277/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.210
# Epoch   0 Batch  278/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.240
# Epoch   0 Batch  279/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.068
# Epoch   0 Batch  280/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.114
# Epoch   0 Batch  281/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.006
# Epoch   0 Batch  282/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.217
# Epoch   0 Batch  283/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.896
# Epoch   0 Batch  284/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.487
# Epoch   0 Batch  285/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.878
# Epoch   0 Batch  286/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.335
# Epoch   0 Batch  287/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.166
# Epoch   0 Batch  288/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.096
# Epoch   0 Batch  289/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.173
# Epoch   0 Batch  290/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.316
# Epoch   0 Batch  291/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.418
# Epoch   0 Batch  292/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.921
# Epoch   0 Batch  293/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.038
# Epoch   0 Batch  294/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.590
# Epoch   0 Batch  295/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.283
# Epoch   0 Batch  296/137861 - Train Accuracy:  0.125, Validation Accuracy:  0.059, Loss:  5.155
# Epoch   0 Batch  297/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.886
# Epoch   0 Batch  298/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.955
# Epoch   0 Batch  299/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.166
# Epoch   0 Batch  300/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.256
# Epoch   0 Batch  301/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.165
# Epoch   0 Batch  302/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.982
# Epoch   0 Batch  303/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.214
# Epoch   0 Batch  304/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.446
# Epoch   0 Batch  305/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.133
# Epoch   0 Batch  306/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  3.867
# Epoch   0 Batch  307/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.408
# Epoch   0 Batch  308/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.855
# Epoch   0 Batch  309/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.050
# Epoch   0 Batch  310/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.528
# Epoch   0 Batch  311/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.116
# Epoch   0 Batch  312/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.298
# Epoch   0 Batch  313/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.302
# Epoch   0 Batch  314/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.271
# Epoch   0 Batch  315/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.846
# Epoch   0 Batch  316/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.261
# Epoch   0 Batch  317/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.004
# Epoch   0 Batch  318/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.420
# Epoch   0 Batch  319/137861 - Train Accuracy:  0.105, Validation Accuracy:  0.111, Loss:  4.143
# Epoch   0 Batch  320/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.938
# Epoch   0 Batch  321/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.309
# Epoch   0 Batch  322/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.846
# Epoch   0 Batch  323/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.278
# Epoch   0 Batch  324/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.095
# Epoch   0 Batch  325/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.211
# Epoch   0 Batch  326/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.119
# Epoch   0 Batch  327/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.806
# Epoch   0 Batch  328/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.259
# Epoch   0 Batch  329/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.347
# Epoch   0 Batch  330/137861 - Train Accuracy:  0.105, Validation Accuracy:  0.111, Loss:  4.224
# Epoch   0 Batch  331/137861 - Train Accuracy:  0.105, Validation Accuracy:  0.111, Loss:  4.202
# Epoch   0 Batch  332/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.205
# Epoch   0 Batch  333/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.176
# Epoch   0 Batch  334/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.316
# Epoch   0 Batch  335/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.910
# Epoch   0 Batch  336/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.255
# Epoch   0 Batch  337/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.090
# Epoch   0 Batch  338/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.453
# Epoch   0 Batch  339/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.221
# Epoch   0 Batch  340/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.935
# Epoch   0 Batch  341/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.184
# Epoch   0 Batch  342/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  5.788
# Epoch   0 Batch  343/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.044
# Epoch   0 Batch  344/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.127
# Epoch   0 Batch  345/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.128
# Epoch   0 Batch  346/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.179
# Epoch   0 Batch  347/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.125
# Epoch   0 Batch  348/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.136
# Epoch   0 Batch  349/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.059
# Epoch   0 Batch  350/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.063
# Epoch   0 Batch  351/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.092
# Epoch   0 Batch  352/137861 - Train Accuracy:  0.100, Validation Accuracy:  0.111, Loss:  4.144
# Epoch   0 Batch  353/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.034
# Epoch   0 Batch  354/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.354
# Epoch   0 Batch  355/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.297
# Epoch   0 Batch  356/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.959
# Epoch   0 Batch  357/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.001
# Epoch   0 Batch  358/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.956
# Epoch   0 Batch  359/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.904
# Epoch   0 Batch  360/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.847
# Epoch   0 Batch  361/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.272
# Epoch   0 Batch  362/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.038
# Epoch   0 Batch  363/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.440
# Epoch   0 Batch  364/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.524
# Epoch   0 Batch  365/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.039
# Epoch   0 Batch  366/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.956
# Epoch   0 Batch  367/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.321
# Epoch   0 Batch  368/137861 - Train Accuracy:  0.105, Validation Accuracy:  0.111, Loss:  4.122
# Epoch   0 Batch  369/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  5.648
# Epoch   0 Batch  370/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.295
# Epoch   0 Batch  371/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.861
# Epoch   0 Batch  372/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.142
# Epoch   0 Batch  373/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.159
# Epoch   0 Batch  374/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.929
# Epoch   0 Batch  375/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.533
# Epoch   0 Batch  376/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.930
# Epoch   0 Batch  377/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.122
# Epoch   0 Batch  378/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.084
# Epoch   0 Batch  379/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.370
# Epoch   0 Batch  380/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.138
# Epoch   0 Batch  381/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.756
# Epoch   0 Batch  382/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.311
# Epoch   0 Batch  383/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.262
# Epoch   0 Batch  384/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.226
# Epoch   0 Batch  385/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.252
# Epoch   0 Batch  386/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.453
# Epoch   0 Batch  387/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.867
# Epoch   0 Batch  388/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.928
# Epoch   0 Batch  389/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.101
# Epoch   0 Batch  390/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.794
# Epoch   0 Batch  391/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.076
# Epoch   0 Batch  392/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.319
# Epoch   0 Batch  393/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.115
# Epoch   0 Batch  394/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.064
# Epoch   0 Batch  395/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.106
# Epoch   0 Batch  396/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.859
# Epoch   0 Batch  397/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.920
# Epoch   0 Batch  398/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.790
# Epoch   0 Batch  399/137861 - Train Accuracy:  0.105, Validation Accuracy:  0.111, Loss:  4.276
# Epoch   0 Batch  400/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.882
# Epoch   0 Batch  401/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.091
# Epoch   0 Batch  402/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.166
# Epoch   0 Batch  403/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.205
# Epoch   0 Batch  404/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.058
# Epoch   0 Batch  405/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.116
# Epoch   0 Batch  406/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.289
# Epoch   0 Batch  407/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.032
# Epoch   0 Batch  408/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.946
# Epoch   0 Batch  409/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.111, Loss:  4.203
# Epoch   0 Batch  410/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.353
# Epoch   0 Batch  411/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.378
# Epoch   0 Batch  412/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.351
# Epoch   0 Batch  413/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.882
# Epoch   0 Batch  414/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.009
# Epoch   0 Batch  415/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  4.021
# Epoch   0 Batch  416/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  5.058
# Epoch   0 Batch  417/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.111, Loss:  3.829
# Epoch   0 Batch  418/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.111, Loss:  4.323
# Epoch   0 Batch  419/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.978
# Epoch   0 Batch  420/137861 - Train Accuracy:  0.091, Validation Accuracy:  0.059, Loss:  5.836
# Epoch   0 Batch  421/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.968
# Epoch   0 Batch  422/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.003
# Epoch   0 Batch  423/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.329
# Epoch   0 Batch  424/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.938
# Epoch   0 Batch  425/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.971
# Epoch   0 Batch  426/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.436
# Epoch   0 Batch  427/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  4.276
# Epoch   0 Batch  428/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.404
# Epoch   0 Batch  429/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.109
# Epoch   0 Batch  430/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  5.087
# Epoch   0 Batch  431/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.030
# Epoch   0 Batch  432/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.760
# Epoch   0 Batch  433/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.866
# Epoch   0 Batch  434/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  4.391
# Epoch   0 Batch  435/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.028
# Epoch   0 Batch  436/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.800
# Epoch   0 Batch  437/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.296
# Epoch   0 Batch  438/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.185
# Epoch   0 Batch  439/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.803
# Epoch   0 Batch  440/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.202
# Epoch   0 Batch  441/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.980
# Epoch   0 Batch  442/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.101
# Epoch   0 Batch  443/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.135
# Epoch   0 Batch  444/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.460
# Epoch   0 Batch  445/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  5.327
# Epoch   0 Batch  446/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.060
# Epoch   0 Batch  447/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.141
# Epoch   0 Batch  448/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  5.360
# Epoch   0 Batch  449/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.198
# Epoch   0 Batch  450/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.176
# Epoch   0 Batch  451/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.486
# Epoch   0 Batch  452/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.919
# Epoch   0 Batch  453/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.145
# Epoch   0 Batch  454/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  4.086
# Epoch   0 Batch  455/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.004
# Epoch   0 Batch  456/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.777
# Epoch   0 Batch  457/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.813
# Epoch   0 Batch  458/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.152
# Epoch   0 Batch  459/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.128
# Epoch   0 Batch  460/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.760
# Epoch   0 Batch  461/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.794
# Epoch   0 Batch  462/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.089
# Epoch   0 Batch  463/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.986
# Epoch   0 Batch  464/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.120
# Epoch   0 Batch  465/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.075
# Epoch   0 Batch  466/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.922
# Epoch   0 Batch  467/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.980
# Epoch   0 Batch  468/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.303
# Epoch   0 Batch  469/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.828
# Epoch   0 Batch  470/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.852
# Epoch   0 Batch  471/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.034
# Epoch   0 Batch  472/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.409
# Epoch   0 Batch  473/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.159
# Epoch   0 Batch  474/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.933
# Epoch   0 Batch  475/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.339
# Epoch   0 Batch  476/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.860
# Epoch   0 Batch  477/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.140
# Epoch   0 Batch  478/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.057
# Epoch   0 Batch  479/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.022
# Epoch   0 Batch  480/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.809
# Epoch   0 Batch  481/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.171
# Epoch   0 Batch  482/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.304
# Epoch   0 Batch  483/137861 - Train Accuracy:  0.125, Validation Accuracy:  0.059, Loss:  5.064
# Epoch   0 Batch  484/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.070
# Epoch   0 Batch  485/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.731
# Epoch   0 Batch  486/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.429
# Epoch   0 Batch  487/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  4.162
# Epoch   0 Batch  488/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.831
# Epoch   0 Batch  489/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.329
# Epoch   0 Batch  490/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.179
# Epoch   0 Batch  491/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.160
# Epoch   0 Batch  492/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.101
# Epoch   0 Batch  493/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.867
# Epoch   0 Batch  494/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.720
# Epoch   0 Batch  495/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  3.766
# Epoch   0 Batch  496/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.894
# Epoch   0 Batch  497/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.809
# Epoch   0 Batch  498/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.822
# Epoch   0 Batch  499/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.834
# ...
# Epoch   0 Batch 1182/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.773
# Epoch   0 Batch 1183/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.178
# Epoch   0 Batch 1184/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.638
# Epoch   0 Batch 1185/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.055
# Epoch   0 Batch 1186/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.715
# Epoch   0 Batch 1187/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.782
# Epoch   0 Batch 1188/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.755
# Epoch   0 Batch 1189/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.523
# Epoch   0 Batch 1190/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.122
# Epoch   0 Batch 1191/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.043
# Epoch   0 Batch 1192/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  3.879
# Epoch   0 Batch 1193/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.585
# Epoch   0 Batch 1194/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.110
# Epoch   0 Batch 1195/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.757
# Epoch   0 Batch 1196/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.923
# Epoch   0 Batch 1197/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.905
# Epoch   0 Batch 1198/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.913
# Epoch   0 Batch 1199/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.005
# Epoch   0 Batch 1200/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.948
# Epoch   0 Batch 1201/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.627
# Epoch   0 Batch 1202/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.583
# Epoch   0 Batch 1203/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.823
# Epoch   0 Batch 1204/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.778
# Epoch   0 Batch 1205/137861 - Train Accuracy:  0.154, Validation Accuracy:  0.059, Loss:  3.546
# Epoch   0 Batch 1206/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  4.013
# Epoch   0 Batch 1207/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.158
# Epoch   0 Batch 1208/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.599
# Epoch   0 Batch 1209/137861 - Train Accuracy:  0.167, Validation Accuracy:  0.059, Loss:  3.485
# Epoch   0 Batch 1210/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.573
# Epoch   0 Batch 1211/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.685
# Epoch   0 Batch 1212/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.086
# Epoch   0 Batch 1213/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.817
# Epoch   0 Batch 1214/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.006
# Epoch   0 Batch 1215/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.671
# Epoch   0 Batch 1216/137861 - Train Accuracy:  0.050, Validation Accuracy:  0.059, Loss:  4.051
# Epoch   0 Batch 1217/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.776
# Epoch   0 Batch 1218/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.694
# Epoch   0 Batch 1219/137861 - Train Accuracy:  0.125, Validation Accuracy:  0.059, Loss:  4.945
# Epoch   0 Batch 1220/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.600
# Epoch   0 Batch 1221/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.226
# Epoch   0 Batch 1222/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.978
# Epoch   0 Batch 1223/137861 - Train Accuracy:  0.077, Validation Accuracy:  0.059, Loss:  3.913
# Epoch   0 Batch 1224/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.577
# Epoch   0 Batch 1225/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  3.827
# Epoch   0 Batch 1226/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.882
# Epoch   0 Batch 1227/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.942
# Epoch   0 Batch 1228/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.756
# Epoch   0 Batch 1229/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  3.928
# Epoch   0 Batch 1230/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.294
# Epoch   0 Batch 1231/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.957
# Epoch   0 Batch 1232/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  3.948
# Epoch   0 Batch 1233/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.469
# Epoch   0 Batch 1234/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  3.697
# Epoch   0 Batch 1235/137861 - Train Accuracy:  0.071, Validation Accuracy:  0.059, Loss:  3.736
# Epoch   0 Batch 1236/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.221
# Epoch   0 Batch 1237/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  3.861
# Epoch   0 Batch 1238/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.847
# Epoch   0 Batch 1239/137861 - Train Accuracy:  0.143, Validation Accuracy:  0.059, Loss:  3.997
# Epoch   0 Batch 1240/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.839
# Epoch   0 Batch 1241/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.933
# Epoch   0 Batch 1242/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.829
# Epoch   0 Batch 1243/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.711
# Epoch   0 Batch 1244/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.871
# Epoch   0 Batch 1245/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.982
# Epoch   0 Batch 1246/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.839
# Epoch   0 Batch 1247/137861 - Train Accuracy:  0.077, Validation Accuracy:  0.059, Loss:  3.571
# Epoch   0 Batch 1248/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.878
# Epoch   0 Batch 1249/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.535
# Epoch   0 Batch 1250/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.609
# Epoch   0 Batch 1251/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.633
# Epoch   0 Batch 1252/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.151
# Epoch   0 Batch 1253/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  4.011
# Epoch   0 Batch 1254/137861 - Train Accuracy:  0.111, Validation Accuracy:  0.059, Loss:  3.612
# Epoch   0 Batch 1255/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.666
# Epoch   0 Batch 1256/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.995
# Epoch   0 Batch 1257/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.077
# Epoch   0 Batch 1258/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.963
# Epoch   0 Batch 1259/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.775
# Epoch   0 Batch 1260/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.943
# Epoch   0 Batch 1261/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.724
# Epoch   0 Batch 1262/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.611
# Epoch   0 Batch 1263/137861 - Train Accuracy:  0.077, Validation Accuracy:  0.059, Loss:  3.898
# Epoch   0 Batch 1264/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.036
# Epoch   0 Batch 1265/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.226
# Epoch   0 Batch 1266/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.128
# Epoch   0 Batch 1267/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.825
# Epoch   0 Batch 1268/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.983
# Epoch   0 Batch 1269/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.908
# Epoch   0 Batch 1270/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.789
# Epoch   0 Batch 1271/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.929
# Epoch   0 Batch 1272/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.970
# Epoch   0 Batch 1273/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.748
# Epoch   0 Batch 1274/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  3.900
# Epoch   0 Batch 1275/137861 - Train Accuracy:  0.125, Validation Accuracy:  0.059, Loss:  4.581
# Epoch   0 Batch 1276/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  5.147
# Epoch   0 Batch 1277/137861 - Train Accuracy:  0.167, Validation Accuracy:  0.059, Loss:  3.478
# Epoch   0 Batch 1278/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.781
# Epoch   0 Batch 1279/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  3.755
# Epoch   0 Batch 1280/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.990
# Epoch   0 Batch 1281/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.284
# Epoch   0 Batch 1282/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.853
# Epoch   0 Batch 1283/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.798
# Epoch   0 Batch 1284/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  4.014
# Epoch   0 Batch 1285/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.623
# Epoch   0 Batch 1286/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.051
# Epoch   0 Batch 1287/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.678
# Epoch   0 Batch 1288/137861 - Train Accuracy:  0.000, Validation Accuracy:  0.059, Loss:  4.901
# Epoch   0 Batch 1289/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.014
# Epoch   0 Batch 1290/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.920
# Epoch   0 Batch 1291/137861 - Train Accuracy:  0.100, Validation Accuracy:  0.059, Loss:  4.696
# Epoch   0 Batch 1292/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.642
# Epoch   0 Batch 1293/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.948
# Epoch   0 Batch 1294/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.925
# Epoch   0 Batch 1295/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.477
# Epoch   0 Batch 1296/137861 - Train Accuracy:  0.053, Validation Accuracy:  0.059, Loss:  3.909
# Epoch   0 Batch 1297/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.972
# Epoch   0 Batch 1298/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.905
# Epoch   0 Batch 1299/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.960
# Epoch   0 Batch 1300/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  3.348
# Epoch   0 Batch 1301/137861 - Train Accuracy:  0.050, Validation Accuracy:  0.059, Loss:  3.987
# Epoch   0 Batch 1302/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.853
# Epoch   0 Batch 1303/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.575
# Epoch   0 Batch 1304/137861 - Train Accuracy:  0.077, Validation Accuracy:  0.059, Loss:  5.508
# Epoch   0 Batch 1305/137861 - Train Accuracy:  0.083, Validation Accuracy:  0.059, Loss:  4.809
# Epoch   0 Batch 1306/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.028
# Epoch   0 Batch 1307/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  4.330
# Epoch   0 Batch 1308/137861 - Train Accuracy:  0.077, Validation Accuracy:  0.059, Loss:  3.926
# Epoch   0 Batch 1309/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.912
# Epoch   0 Batch 1310/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  4.006
# Epoch   0 Batch 1311/137861 - Train Accuracy:  0.077, Validation Accuracy:  0.059, Loss:  4.852
# Epoch   0 Batch 1312/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.682
# Epoch   0 Batch 1313/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.973
# Epoch   0 Batch 1314/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  3.755
# Epoch   0 Batch 1315/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.683
# Epoch   0 Batch 1316/137861 - Train Accuracy:  0.059, Validation Accuracy:  0.059, Loss:  3.930
# Epoch   0 Batch 1317/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.632
# Epoch   0 Batch 1318/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.866
# Epoch   0 Batch 1319/137861 - Train Accuracy:  0.062, Validation Accuracy:  0.059, Loss:  3.823
# Epoch   0 Batch 1320/137861 - Train Accuracy:  0.056, Validation Accuracy:  0.059, Loss:  4.042
# Epoch   0 Batch 1321/137861 - Train Accuracy:  0.067, Validation Accuracy:  0.059, Loss:  3.744
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d7dd20c512f1> in <module>()
#      42                  lr: learning_rate,
#      43                  sequence_length: target_batch.shape[1],
# ---> 44                  keep_prob: keep_probability})
#      45
#      46             batch_train_logits = sess.run(
#
# C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# C:\Users\Andreas\AppData\Local\conda\conda\envs\dl\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """    
    return text_to_ids_single(sentence, vocab_to_int)[0]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3275c3359f72> in <module>()
#      10 with tf.Session(graph=loaded_graph) as sess:
#      11     # Load saved model
# ---> 12     loader = tf.train.import_meta_graph(load_path + '.meta')
#      13     loader.restore(sess, load_path)
#      14
#
# NameError: name 'load_path' is not defined

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
